# %% [markdown]
# # Limiting Behavior of the BID Lattice

# %%
#Required packages
using EvolutionaryModels
using DifferentialEquations
using Plots
using LaTeXStrings
using Catalyst

# %%
##################### Pure Immigration
K_i = (2.8)
N_0 = 0
t = 18

complexgraph(EvolutionaryModels.pure_immigration)
# Out:
# Graph("G", true, "dot", Catalyst.Statement[Catalyst.Node("<∅>", OrderedCollections.OrderedDict{Symbol, Union{Catalyst.Html, String}}(:shape => "circle", :color => "#6C9AC3")), Catalyst.Node("<A>", OrderedCollections.OrderedDict{Symbol, Union{Catalyst.Html, String}}(:shape => "circle", :color => "#6C9AC3")), Catalyst.Edge(Catalyst.NodeID[Catalyst.NodeID("<∅>", "", ""), Catalyst.NodeID("<A>", "", "")], OrderedCollections.OrderedDict{Symbol, Union{Catalyst.Html, String}}())], OrderedCollections.OrderedDict{Symbol, Union{Catalyst.Html, String}}(:rankdir => "LR"), OrderedCollections.OrderedDict{Symbol, Union{Catalyst.Html, String}}(:shape => "plain", :style => "filled", :color => "white"), OrderedCollections.OrderedDict{Symbol, Union{Catalyst.Html, String}}(:splines => "splines"))

# %%
deficiency(EvolutionaryModels.pure_immigration)
# Out:
# 0

# %%
odesys = convert(ODESystem, EvolutionaryModels.pure_immigration)
# Out:
# Model ##ReactionSystem#291 with 1 equations
# States (1):
#   A(t)
# Parameters (1):
#   K_i

# %%
 # SDEProblem for CLE
sprob = SDEProblem( EvolutionaryModels.pure_immigration,u0, tspan, p)

# solve and plot, tstops is used to specify enough points
# that the plot looks well-resolved
sol = solve(sprob, LambaEM(), tstops=range(0., step=4e-3, length=1001))
plot(sol)

# %%
using OrdinaryDiffEq
p     = [:K_i => 2.8]
tspan = (0.0,18.0)
u0    = [:A => 0]
op    = ODEProblem(EvolutionaryModels.pure_immigration, u0, tspan, p)
sol   = solve(op, Tsit5())       # use Tsit5 ODE solver
plot(sol, lw=2)

# %%
##################### Pure Immigration
K_i = (2.8)
N_0 = 0
t = 18
prob = DiscreteProblem(EvolutionaryModels.pure_immigration, [N_0], (0.0,t), K_i)
# Out:
# MethodError: no method matching create_array(::Type{Float64}, ::Type{Float64}, ::Val{1}, ::Val{1}, ::Float64)
# Closest candidates are:
#   create_array(::Type{<:StaticArraysCore.MArray}, ::Any, ::Val, ::Val{dims}, ::Any...) where dims at ~/.julia/packages/SymbolicUtils/vnuIf/src/code.jl:541
#   create_array(::Type{<:LabelledArrays.LArray}, ::Any, ::Val, ::Val{dims}, ::Any...) where dims at ~/.julia/packages/SymbolicUtils/vnuIf/src/code.jl:555
#   create_array(::Type{<:LinearAlgebra.UpperTriangular{T, P}}, ::Any, ::Val, ::Val, ::Any...) where {T, P} at ~/.julia/packages/SymbolicUtils/vnuIf/src/code.jl:523
#   ...
#
# Stacktrace:
#  [1] varmap_to_vars(varmap::Float64, varlist::Vector{Sym{Real, Base.ImmutableDict{DataType, Any}}}; defaults::Dict{Any, Any}, check::Bool, toterm::Function, promotetoconcrete::Nothing, tofloat::Bool, use_union::Bool)
#    @ ModelingToolkit ~/.julia/packages/ModelingToolkit/tMgaW/src/variables.jl:79
#  [2] DiscreteProblem(sys::JumpSystem{ArrayPartition{Any, Tuple{Vector{MassActionJump}, Vector{ConstantRateJump}, Vector{VariableRateJump}}}}, u0map::Vector{Int64}, tspan::Tuple{Float64, Int64}, parammap::Float64; checkbounds::Bool, use_union::Bool, kwargs::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#    @ ModelingToolkit ~/.julia/packages/ModelingToolkit/tMgaW/src/systems/jumps/jumpsystem.jl:235
#  [3] DiscreteProblem(sys::JumpSystem{ArrayPartition{Any, Tuple{Vector{MassActionJump}, Vector{ConstantRateJump}, Vector{VariableRateJump}}}}, u0map::Vector{Int64}, tspan::Tuple{Float64, Int64}, parammap::Float64)
#    @ ModelingToolkit ~/.julia/packages/ModelingToolkit/tMgaW/src/systems/jumps/jumpsystem.jl:227
#  [4] DiscreteProblem(::ReactionSystem{Nothing, Catalyst.NetworkProperties{Int64, Term{Real, Base.ImmutableDict{DataType, Any}}}}, ::Vector{Int64}, ::Tuple{Float64, Int64}, ::Float64; name::Symbol, combinatoric_ratelaws::Bool, checks::Bool, kwargs::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#    @ Catalyst ~/.julia/packages/Catalyst/JocXA/src/reactionsystem.jl:1364
#  [5] DiscreteProblem(::ReactionSystem{Nothing, Catalyst.NetworkProperties{Int64, Term{Real, Base.ImmutableDict{DataType, Any}}}}, ::Vector{Int64}, ::Tuple{Float64, Int64}, ::Float64)
#    @ Catalyst ~/.julia/packages/Catalyst/JocXA/src/reactionsystem.jl:1361
#  [6] top-level scope
#    @ In[4]:5
#  [7] eval
#    @ ./boot.jl:373 [inlined]
#  [8] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1196
# WARNING: both Symbolics and ModelingToolkit export "degree"; uses of it in module Catalyst must be qualified
# WARNING: both Symbolics and ModelingToolkit export "infimum"; uses of it in module Catalyst must be qualified
# WARNING: both Symbolics and ModelingToolkit export "supremum"; uses of it in module Catalyst must be qualified

# %%
##################### Pure Immigration
K_i = (2.8)
N_0 = 0
t = 18

prob = DiscreteProblem(pure_immigration, [N_0], (0.0,t), K_i)
jump_prob = JumpProblem(pure_immigration, prob, Direct())
solutions = EvolutionaryModels.SamplesGillespie(jump_prob,SSAStepper(),100)
trajectories = solutionstoDF(solutions)
plotCRNGillespie(solutions)



# Let's compare
nmostres = 2000
FinalMostra = SampleFinal(nmostres,jump_prob,SSAStepper())
Nmin = minimum(FinalMostra[1])
Nmax = maximum(FinalMostra[1])
orange = Nmin:1:Nmax
Distro = PureImmigration.(K_i,t,orange,N_0)
DistroUs = P_BID.(orange,N_0,t,0.000000001,0.00001,K_i,0)
histogram(FinalMostra[1],normalize = true)
#plot!(orange,Distro)
plot!(orange,DistroUs)
# Out:
# MethodError: no method matching create_array(::Type{Float64}, ::Type{Float64}, ::Val{1}, ::Val{1}, ::Float64)
# Closest candidates are:
#   create_array(::Type{<:StaticArraysCore.MArray}, ::Any, ::Val, ::Val{dims}, ::Any...) where dims at ~/.julia/packages/SymbolicUtils/vnuIf/src/code.jl:541
#   create_array(::Type{<:LabelledArrays.LArray}, ::Any, ::Val, ::Val{dims}, ::Any...) where dims at ~/.julia/packages/SymbolicUtils/vnuIf/src/code.jl:555
#   create_array(::Type{<:LinearAlgebra.UpperTriangular{T, P}}, ::Any, ::Val, ::Val, ::Any...) where {T, P} at ~/.julia/packages/SymbolicUtils/vnuIf/src/code.jl:523
#   ...
#
# Stacktrace:
#  [1] varmap_to_vars(varmap::Float64, varlist::Vector{Sym{Real, Base.ImmutableDict{DataType, Any}}}; defaults::Dict{Any, Any}, check::Bool, toterm::Function, promotetoconcrete::Nothing, tofloat::Bool, use_union::Bool)
#    @ ModelingToolkit ~/.julia/packages/ModelingToolkit/tMgaW/src/variables.jl:79
#  [2] DiscreteProblem(sys::JumpSystem{ArrayPartition{Any, Tuple{Vector{MassActionJump}, Vector{ConstantRateJump}, Vector{VariableRateJump}}}}, u0map::Vector{Int64}, tspan::Tuple{Float64, Int64}, parammap::Float64; checkbounds::Bool, use_union::Bool, kwargs::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#    @ ModelingToolkit ~/.julia/packages/ModelingToolkit/tMgaW/src/systems/jumps/jumpsystem.jl:235
#  [3] DiscreteProblem(sys::JumpSystem{ArrayPartition{Any, Tuple{Vector{MassActionJump}, Vector{ConstantRateJump}, Vector{VariableRateJump}}}}, u0map::Vector{Int64}, tspan::Tuple{Float64, Int64}, parammap::Float64)
#    @ ModelingToolkit ~/.julia/packages/ModelingToolkit/tMgaW/src/systems/jumps/jumpsystem.jl:227
#  [4] DiscreteProblem(::ReactionSystem{Nothing, Catalyst.NetworkProperties{Int64, Term{Real, Base.ImmutableDict{DataType, Any}}}}, ::Vector{Int64}, ::Tuple{Float64, Int64}, ::Float64; name::Symbol, combinatoric_ratelaws::Bool, checks::Bool, kwargs::Base.Pairs{Symbol, Union{}, Tuple{}, NamedTuple{(), Tuple{}}})
#    @ Catalyst ~/.julia/packages/Catalyst/JocXA/src/reactionsystem.jl:1364
#  [5] DiscreteProblem(::ReactionSystem{Nothing, Catalyst.NetworkProperties{Int64, Term{Real, Base.ImmutableDict{DataType, Any}}}}, ::Vector{Int64}, ::Tuple{Float64, Int64}, ::Float64)
#    @ Catalyst ~/.julia/packages/Catalyst/JocXA/src/reactionsystem.jl:1361
#  [6] top-level scope
#    @ In[5]:6
#  [7] eval
#    @ ./boot.jl:373 [inlined]
#  [8] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1196
